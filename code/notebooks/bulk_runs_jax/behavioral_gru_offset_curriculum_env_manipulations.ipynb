# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import jax
import seaborn as sns

jax.config.update('jax_platforms', 'cpu')

plt.rcParams['font.family'] = 'Helvetica Light'

from behavioral_plotting import (
    plot_session,
    load_odor_site_df,
    plot_patch_statistics_per_session,
    plot_patch_statistics_across_dfs,
    plot_patch_statistics,
    plot_multi_df_accuracy_heatmap,
    plot_leave_probabilities,
    append_index_phase,
    plot_grouped_mean_std,
    plot_stop_fraction,
    plot_first_patch_rewards_vs_other_prefactors,
    plot_rewards_by_patch_sequence,
    plot_patch_type_scatter_across_dfs,
    odor_colors,
    plot_patch_traj,
)
from aux_funcs import format_plot
from nb_analysis_tools import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# had to clear the font cache to get the Helvetica Light font to work.
# If you see a warning about missing fonts, run this cell and restart the kernel.

# import matplotlib as mpl
# import shutil, os

# # Find and delete the font cache
# cache_dir = mpl.get_cachedir()
# print(f"Cache dir: {cache_dir}")

# # Delete cache files
# for f in os.listdir(cache_dir):
#     if f.endswith('.json') or f.endswith('.cache'):
#         os.remove(os.path.join(cache_dir, f))
#         print(f"Deleted: {f}")

# print("Done — restart the kernel now")

# %%
from pathlib import Path

def find_trajectories(results_dir):
    """Return sorted list of traj_*.pkl path strings under results_dir."""
    root = Path(results_dir)
    return sorted(str(p) for p in root.rglob('traj_*.pkl'))

# %%
CURRICULUM_TRAINED_NETWORKS_LOW_BECOMES_HIGH = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_low_becomes_high'
)
print(f'LOW_BECOMES_HIGH: {len(CURRICULUM_TRAINED_NETWORKS_LOW_BECOMES_HIGH)} trajectories')
# Out:
# LOW_BECOMES_HIGH: 30 trajectories

# %%
CURRICULUM_TRAINED_NETWORKS_HIGH_BECOMES_LOW = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_high_becomes_low'
)
print(f'high_becomes_low: {len(CURRICULUM_TRAINED_NETWORKS_HIGH_BECOMES_LOW)} trajectories')
# Out:
# high_becomes_low: 30 trajectories

# %%
CURRICULUM_TRAINED_NETWORKS_LOW_BECOMES_HIGH_SLOW = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_low_becomes_high_lr_1e-5'
)
print(f'low_becomes_high_slow: {len(CURRICULUM_TRAINED_NETWORKS_LOW_BECOMES_HIGH_SLOW)} trajectories')
# Out:
# low_becomes_high_slow: 30 trajectories

# %%
CURRICULUM_TRAINED_NETWORKS_V1_STABLE = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_v1_no_change'
)

# %%
CURRICULUM_TRAINED_NETWORKS_INTERPATCH_LENGTHEN = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_interpatch_lengthen'
)

# %%
CURRICULUM_TRAINED_NETWORKS_INTERPATCH_SHORTEN = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_interpatch_shorten'
)

# %%
CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen'
)

CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_1000 = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_1000'
)

CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250 = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250'
)

CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250_FROZEN = find_trajectories(
    '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250_frozen'
)

# %% [markdown]
# ## Behavioral traces

# %%
for i, data_path in enumerate([
    CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250_FROZEN[0],
    CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250_FROZEN[5],
]):
    plot_session(
        data_path,
        session_idx=0,
        xlim=(0, 400),
        max_reward_param=40,
        max_reward_sites=30,
        use_fixed_colors=True,
        color_by_reward_param=False
    )
# Out:
# [0.  0.6 0.8]
# [0.  0.6 0.8]

# %%
for i, data_path in enumerate([
    CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250[0],
    CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250[5],
]):
    plot_session(
        data_path,
        session_idx=1,
        xlim=(0, 400),
        max_reward_param=40,
        max_reward_sites=30,
        use_fixed_colors=True,
        color_by_reward_param=False
    )
# Out:
# [0.  0.6 0.8]
# [0.  0.6 0.8]

# %% [markdown]
# ## Odor site data loading

# %%
dfs = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_LOW_BECOMES_HIGH)
]
# Out:
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated

# %%
dfs_high_becomes_low = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_HIGH_BECOMES_LOW)
]
# Out:
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated

# %%
dfs_low_becomes_high_slow = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_LOW_BECOMES_HIGH_SLOW)
]
# Out:
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated

# %%
dfs_v1_stable = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_V1_STABLE)
]
# Out:
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated

# %%
dfs_v1_interpatch_lengthen = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_INTERPATCH_LENGTHEN)
]
# Out:
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated

# %%
dfs_v1_interpatch_shorten = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_INTERPATCH_SHORTEN)
]
# Out:
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated

# %%
print(CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250)
# Out:
# ['../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_00/traj_000000.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_00/traj_000002.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_00/traj_000004.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_00/traj_000006.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_00/traj_000008.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000010.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000012.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000014.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000016.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000018.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000020.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000022.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000024.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000026.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000028.pkl', '../../../results/fixed_exp_gru_initial_prob_offset_intersite_lengthen_epoch_0250/step_01/traj_000030.pkl']

# %%
dfs_v1_intersite_lengthen = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN)
]
# Out:
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated

# %%
# dfs_v1_intersite_lengthen_epoch_1000 = [
#     load_odor_site_df(x, nn_num=nn_num, brief=True)
#     for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_1000)
# ]

# %%
dfs_v1_intersite_lengthen_epoch_0250 = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250)
]
# Out:
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated
# Session data loaded
# Session summaries generated

# %%
dfs_v1_intersite_lengthen_epoch_0250_frozen = [
    load_odor_site_df(x, nn_num=nn_num, brief=True)
    for nn_num, x in enumerate(CURRICULUM_TRAINED_NETWORKS_INTERSITE_LENGTHEN_EPOCH_0250_FROZEN)
]

# %% [markdown]
# ## Mean rewards harvested and probability of reward at leave across sessions

# %%
fig, axes = plt.subplots(1, 2, figsize=(5, 2.5), sharex=True, sharey=True)

x = np.arange(16)   # 0 through 20

# ── Exponential decay curves ──────────────────────────────────────────────
prefactors  = [0,  0.6,  0.8]   # one per curve
decay_rates = [1,  1/20,  1/20]   # one per curve

for (prefactor, decay_rate, color) in zip(prefactors, decay_rates, odor_colors):
    y = prefactor * np.exp(-decay_rate * x)
    axes[0].plot(x, y, color=color, lw=1)
    axes[0].scatter(x, y, color=color, s=20)
axes[0].set_xlabel('Accumulated reward\nin patch')
axes[0].set_ylabel(r'$P(r_t=1)$')

# ── Exponential decay curves ──────────────────────────────────────────────
prefactors  = [0,  0.6,  0.6]   # one per curve
decay_rates = [1,  1/20,  1/20]   # one per curve

for (prefactor, decay_rate, color) in zip(prefactors, decay_rates, odor_colors):
    y = prefactor * np.exp(-decay_rate * x)
    axes[1].plot(x, y, color=color, lw=1)
    axes[1].scatter(x, y, color=color, s=20)


format_plot(axes)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### High becomes low

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs_high_becomes_low,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.axvline(10, color='grey', ls='--')
    ax.set_xticks(np.arange(0, len(dfs_high_becomes_low), 5))
    ax.set_xticklabels([f'{s}' for s in np.arange(0, len(dfs_high_becomes_low), 5) - 10])
    ax.set_xlabel('Sessions relative to curriculum change')
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
fig, axes = plt.subplots(1, 2, figsize=(5, 2.5), sharex=True, sharey=True)

x = np.arange(16)   # 0 through 20

# ── Exponential decay curves ──────────────────────────────────────────────
prefactors  = [0,  0.6,  0.8]   # one per curve
decay_rates = [1,  1/20,  1/20]   # one per curve

for (prefactor, decay_rate, color) in zip(prefactors, decay_rates, odor_colors):
    y = prefactor * np.exp(-decay_rate * x)
    axes[0].plot(x, y, color=color, lw=1)
    axes[0].scatter(x, y, color=color, s=20)
axes[0].set_xlabel('Accumulated reward\nin patch')
axes[0].set_ylabel(r'$P(r_t=1)$')

# ── Exponential decay curves ──────────────────────────────────────────────
prefactors  = [0,  0.8,  0.8]   # one per curve
decay_rates = [1,  1/20,  1/20]   # one per curve

for (prefactor, decay_rate, color) in zip(prefactors, decay_rates, odor_colors):
    y = prefactor * np.exp(-decay_rate * x)
    axes[1].plot(x, y, color=color, lw=1)
    axes[1].scatter(x, y, color=color, s=20)


format_plot(axes)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Low becomes high

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.axvline(10, color='grey', ls='--')
    ax.set_xticks(np.arange(0, len(dfs), 5))
    ax.set_xticklabels([f'{s}' for s in np.arange(0, len(dfs), 5) - 10])
    ax.set_xlabel('Sessions relative to curriculum change')
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
plot_patch_type_scatter_across_dfs(dfs[:10])
plot_patch_type_scatter_across_dfs(dfs_high_becomes_low[:10])
# Out:
# (<Figure size 400x400 with 2 Axes>,
#  <Axes: title={'center': 'Mean rewards collected'}, xlabel='Patch type 1 rewards collected', ylabel='Patch type 2 rewards collected'>,
#  <Figure size 400x400 with 2 Axes>,
#  <Axes: title={'center': 'Mean patch stops'}, xlabel='Patch type 1 patch stops', ylabel='Patch type 2 patch stops'>)

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs_low_becomes_high_slow,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.axvline(10, color='grey', ls='--')
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs_v1_stable,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.set_xticks(np.arange(0, len(dfs_v1_stable), 5))
    ax.set_xlabel('Sessions')
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
fig_rewards, ax_rewards, fig_stops, ax_stops = plot_patch_type_scatter_across_dfs(
    dfs_v1_stable,
    cbar_label='Session'
)

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs_v1_interpatch_shorten,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.axvline(10, color='grey', ls='--')
    ax.set_xticks(np.arange(0, len(dfs_v1_interpatch_shorten), 5))
    ax.set_xticklabels([f'{s}' for s in np.arange(0, len(dfs_v1_interpatch_shorten), 5) - 10])
    ax.set_xlabel('Sessions relative to curriculum change')
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs_v1_interpatch_lengthen,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.axvline(10, color='grey', ls='--')
    ax.set_xticks(np.arange(0, len(dfs_v1_interpatch_lengthen), 5))
    ax.set_xticklabels([f'{s}' for s in np.arange(0, len(dfs_v1_interpatch_lengthen), 5) - 10])
    ax.set_xlabel('Sessions relative to curriculum change')
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs_v1_intersite_lengthen,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.axvline(10 / 2, color='grey', ls='--')
    ax.set_xticks(np.arange(0, len(dfs_v1_intersite_lengthen_epoch_0250), 5))
    ax.set_xticklabels([f'{s}' for s in np.arange(0, 2 * len(dfs_v1_intersite_lengthen_epoch_0250), 2 * 5) - 10])
    ax.set_xlabel('Sessions relative to curriculum change')
    # ax.set_yscale('log')
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs_v1_intersite_lengthen_epoch_0250,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.axvline(10 / 2, color='grey', ls='--')
    ax.set_xticks(np.arange(0, len(dfs_v1_intersite_lengthen_epoch_0250), 5))
    ax.set_xticklabels([f'{s}' for s in np.arange(0, 2 * len(dfs_v1_intersite_lengthen_epoch_0250), 2 * 5) - 10])
    ax.set_xlabel('Sessions relative to curriculum change')
    # ax.set_yscale('log')
# ax3.set_ylim(0, 50)
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
fig1, ax1, fig2, ax2, fig3, ax3 = plot_patch_statistics_across_dfs(
    dfs_v1_intersite_lengthen_epoch_0250_frozen,
    # xticks=np.arange(5) * 5,
    # xticklabels=[f'{s}' for s in np.arange(500, 701, 50)],
)
for ax in [ax1, ax2, ax3]:
    ax.axvline(5, color='grey', ls='--')
    # ax.set_xticks(np.arange(0, len(dfs_v1_intersite_lengthen_epoch_0250), 5))
    # ax.set_xticklabels([f'{s}' for s in np.arange(0, len(dfs_v1_intersite_lengthen_epoch_0250), 5) - 5])
    ax.set_xlabel('Sessions relative to curriculum change')
    # ax.set_yscale('log')
# ax3.set_ylim(0, 50)
plt.show(fig1)
plt.close(fig1)
plt.show(fig2)
plt.close(fig2)
plt.show(fig3)
plt.close(fig3)

# %%
for i in range(4, 8):
    fig, ax = plot_patch_traj(
        dfs_v1_intersite_lengthen_epoch_0250[i],
        patch_type=2, n_patches=50, ylim=(0, 1000),
        scatter_optout=True,
    )

# %%
for i in range(4, 7):
    fig, ax = plot_patch_traj(
        dfs_v1_intersite_lengthen[i],
        patch_type=2, n_patches=200, ylim=(0, 70),
        scatter_optout=True,
    )
