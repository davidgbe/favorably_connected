# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from pathlib import Path
import jax
import jax.numpy as jnp
from flax.training import checkpoints
from flax import serialization
from agents.a2c_rnn_flax import A2CRNNFlax, init_network_and_params
from environments.components.train_state import create_train_state
from environments.treadmill_env_jax import treadmill_session_default_params
import matplotlib.pyplot as plt

# %%
# --- CONFIGURATION ---
CHECKPOINT_PATH = "../../checkpoints/gru_exp_true_indep_pred_all_tau_seed_8000_seed_8000_2025-10-22_16:45:42.467732/checkpoint_7900"  # path to directory with checkpoint
HIDDEN_SIZE = 64
ACTION_SIZE = 2
OBS_SIZE = 4
RNN_TYPE = "GRU"
VAR_NOISE = 1e-4
LEARNING_RATE = 2.5e-5
SEED = 0
NUM_ENVS = 1

# %%
# --- INITIALIZE NETWORK + TRAIN STATE ---
rng_key = jax.random.key(SEED)
net_init_key, rng_key = jax.random.split(rng_key)

network, params = init_network_and_params(
    hidden_size=HIDDEN_SIZE,
    action_size=ACTION_SIZE,
    obs_size=OBS_SIZE,
    rnn_type=RNN_TYPE,
    var_noise=VAR_NOISE,
    rng_key=net_init_key,
)

train_state = create_train_state(
    rng_key=rng_key,
    obs_size=OBS_SIZE,
    hidden_size=HIDDEN_SIZE,
    num_envs=NUM_ENVS,
    learning_rate=LEARNING_RATE,
    params=params,
)

# --- LOAD CHECKPOINT ---
print(f"Loading checkpoint from {CHECKPOINT_PATH} ...")
ckpt_path = Path(CHECKPOINT_PATH).resolve()

restored = checkpoints.restore_checkpoint(ckpt_dir=ckpt_path, target=None)
if "params" in restored:
    params = restored["params"]
else:
    params = restored
train_state = train_state.replace(params=params)
print("Model loaded successfully!")

# --- PROBE WEIGHTS ---
# For example, list top-level parameter shapes:
flat_params = jax.tree_util.tree_map(lambda x: x.shape, train_state.params)
print("\nParameter shapes:")
print(flat_params)

# Example: access specific weights
# e.g. actor dense layer kernel:
try:
    print("\nActor dense kernel sample:")
    print(train_state.params['actor_dense']['kernel'][:3, :3])
except KeyError:
    print("Could not find 'actor_dense' in params; inspect `flat_params` keys to locate structure.")
# Out:
# Loading checkpoint from ../../checkpoints/gru_exp_true_indep_pred_all_tau_seed_8000_seed_8000_2025-10-22_16:45:42.467732/checkpoint_7900 ...
# Model loaded successfully!
#
# Parameter shapes:
# {'params': {'actor': {'bias': (2,), 'kernel': (64, 2)}, 'critic': {'bias': (1,), 'kernel': (64, 1)}, 'env_quality_prediction': {'bias': (3,), 'kernel': (64, 3)}, 'rnn_actor': {'hn': {'bias': (64,), 'kernel': (64, 64)}, 'hr': {'kernel': (64, 64)}, 'hz': {'kernel': (64, 64)}, 'in': {'bias': (64,), 'kernel': (7, 64)}, 'ir': {'bias': (64,), 'kernel': (7, 64)}, 'iz': {'bias': (64,), 'kernel': (7, 64)}}, 'rnn_critic': {'hn': {'bias': (64,), 'kernel': (64, 64)}, 'hr': {'kernel': (64, 64)}, 'hz': {'kernel': (64, 64)}, 'in': {'bias': (64,), 'kernel': (7, 64)}, 'ir': {'bias': (64,), 'kernel': (7, 64)}, 'iz': {'bias': (64,), 'kernel': (7, 64)}}}}
#
# Actor dense kernel sample:
# Could not find 'actor_dense' in params; inspect `flat_params` keys to locate structure.

# %%
# Plot 1: Actor kernel heatmap
plt.figure(figsize=(5, 4))
plt.imshow(params['params']['actor']['kernel'], aspect='auto', cmap='RdBu_r')
plt.colorbar(label='Weight value')
plt.title('Actor Kernel Heatmap')
plt.xlabel('Output dimension')
plt.ylabel('Input dimension')
plt.tight_layout()

# %%
plt.figure(figsize=(5, 4))
plt.imshow(params['params']['env_quality_prediction']['kernel'], aspect='auto', cmap='RdBu_r')
plt.colorbar(label='Weight value')
plt.title('Environment Quality Prediction Kernel Heatmap')
plt.xlabel('Output dimension')
plt.ylabel('Input dimension')
plt.tight_layout()

# %%
# Get the two kernels
actor_kernel = params['params']['actor']['kernel']
env_quality_kernel = params['params']['env_quality_prediction']['kernel']

print(f"Actor kernel shape: {actor_kernel.shape}")
print(f"Env quality kernel shape: {env_quality_kernel.shape}")

# Get dimensions
input_dim, n_actor = actor_kernel.shape
_, n_env_quality = env_quality_kernel.shape

# Compute pairwise cosine similarities between all columns
# Result will be shape (n_actor, n_env_quality)
cosine_sim_matrix = jnp.zeros((n_actor, n_env_quality))

for i in range(n_actor):
    for j in range(n_env_quality):
        col_actor = actor_kernel[:, i]
        col_env_quality = env_quality_kernel[:, j]
        
        # Compute cosine similarity
        dot_product = jnp.dot(col_actor, col_env_quality)
        norm_actor = jnp.linalg.norm(col_actor)
        norm_env_quality = jnp.linalg.norm(col_env_quality)
        
        cosine_sim_matrix = cosine_sim_matrix.at[i, j].set(
            dot_product / (norm_actor * norm_env_quality)
        )

print(f"\nCosine similarity matrix shape: {cosine_sim_matrix.shape}")
print(f"  (rows = actor columns, cols = env_quality columns)")

# Print statistics
print(f"\nStatistics:")
print(f"  Mean similarity: {jnp.mean(cosine_sim_matrix):.6f}")
print(f"  Std similarity: {jnp.std(cosine_sim_matrix):.6f}")
print(f"  Max similarity: {jnp.max(cosine_sim_matrix):.6f}")
print(f"  Min similarity: {jnp.min(cosine_sim_matrix):.6f}")

# Find the maximum similarity for each actor column
max_sim_per_actor = jnp.max(cosine_sim_matrix, axis=1)
print(f"\nMax similarity per actor column:")
print(f"  Mean: {jnp.mean(max_sim_per_actor):.6f}")
print(f"  Std: {jnp.std(max_sim_per_actor):.6f}")

# Plot the cosine similarity matrix
plt.figure(figsize=(4, 2))
plt.imshow(cosine_sim_matrix, aspect='auto', cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar(label='Cosine sim.')
plt.yticks([0, 1])
# plt.title('Cosine Similarity: Actor Columns vs Env Quality Prediction Columns')
plt.xlabel('Tau prediction readout')
plt.ylabel('Action readout')
plt.tight_layout()
plt.show()
# Out:
# Actor kernel shape: (64, 2)
# Env quality kernel shape: (64, 3)
#
# Cosine similarity matrix shape: (2, 3)
#   (rows = actor columns, cols = env_quality columns)
#
# Statistics:
#   Mean similarity: -0.006247
#   Std similarity: 0.032615
#   Max similarity: 0.047496
#   Min similarity: -0.057904
#
# Max similarity per actor column:
#   Mean: 0.027394
#   Std: 0.020102

# %%
# Get dimensions
input_dim, n_env_quality = env_quality_kernel.shape

# Compute pairwise cosine similarities between all columns (vectorized)
# Normalize each column
norms = jnp.linalg.norm(env_quality_kernel, axis=0, keepdims=True)  # Shape: (1, n_env_quality)
normalized = env_quality_kernel / norms  # Normalize each column
cosine_sim_matrix = jnp.dot(normalized.T, normalized)  # Shape: (n_env_quality, n_env_quality)

print(cosine_sim_matrix)
print(f"\nCosine similarity matrix shape: {cosine_sim_matrix.shape}")
print(f"  (rows = env_quality columns, cols = env_quality columns)")

# Plot the cosine similarity matrix
plt.figure(figsize=(4, 3))
plt.imshow(cosine_sim_matrix, aspect='auto', cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar(label='Cosine sim.')
plt.xlabel('Tau prediction readout')
plt.ylabel('Tau prediction readout')
plt.xticks(np.arange(3), 1 + np.arange(3))
plt.yticks(np.arange(3), 1 + np.arange(3))
plt.tight_layout()
plt.show()
# Out:
# [[0.99992985 0.15748169 0.2235886 ]
#  [0.15748169 0.9999206  0.08139654]
#  [0.2235886  0.08139654 1.0002462 ]]
#
# Cosine similarity matrix shape: (3, 3)
#   (rows = env_quality columns, cols = env_quality columns)

# %%
# Plot 3: All 'in' gates for rnn_actor
# RNN typically has multiple gate types, we're plotting all the 'in' gates
fig, axes = plt.subplots(3, 1, figsize=(4, 10))
axes = axes.flatten()

# Get all the 'in' gate kernels from rnn_critic
in_keys = ['in', 'ir', 'iz']  # Based on your parameter structure
titles = ['in', 'ir', 'iz']

for idx, (key, title) in enumerate(zip(in_keys, titles)):
    if key in params['params']['rnn_actor']:
        kernel = params['params']['rnn_actor'][key]['kernel']
        im = axes[idx].imshow(kernel, aspect='auto', cmap='RdBu_r')
        axes[idx].set_title(f'RNN Actor {title}')
        axes[idx].set_xlabel('Hidden dimension')
        axes[idx].set_ylabel('Input dimension')
        plt.colorbar(im, ax=axes[idx], label='Weight value')

plt.tight_layout()

# %%
# Plot 3: All 'in' gates for rnn_actor
# RNN typically has multiple gate types, we're plotting all the 'in' gates
fig, axes = plt.subplots(3, 1, figsize=(4, 10))
axes = axes.flatten()

# Get all the 'in' gate kernels from rnn_critic
in_keys = ['in', 'ir', 'iz']  # Based on your parameter structure
titles = ['in', 'ir', 'iz']

for idx, (key, title) in enumerate(zip(in_keys, titles)):
    if key in params['params']['rnn_critic']:
        kernel = params['params']['rnn_critic'][key]['kernel']
        im = axes[idx].imshow(kernel, aspect='auto', cmap='RdBu_r')
        axes[idx].set_title(f'RNN Critic {title}')
        axes[idx].set_xlabel('Hidden dimension')
        axes[idx].set_ylabel('Input dimension')
        plt.colorbar(im, ax=axes[idx], label='Weight value')

plt.tight_layout()

# %%
# Plot 3: All 'in' gates for rnn_actor
# RNN typically has multiple gate types, we're plotting all the 'in' gates
fig, axes = plt.subplots(3, 1, figsize=(4, 10))
axes = axes.flatten()

# Get all the 'in' gate kernels from rnn_critic
in_keys = ['hn', 'hr', 'hz']  # Based on your parameter structure
titles = ['hn', 'hr', 'hz']

for idx, (key, title) in enumerate(zip(in_keys, titles)):
    if key in params['params']['rnn_actor']:
        kernel = params['params']['rnn_actor'][key]['kernel']
        im = axes[idx].imshow(kernel, aspect='auto', cmap='RdBu_r')
        axes[idx].set_title(f'RNN actor {title}')
        axes[idx].set_xlabel('Output dimension')
        axes[idx].set_ylabel('Input dimension')
        plt.colorbar(im, ax=axes[idx], label='Weight value')

plt.tight_layout()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist, squareform

# Get all the 'in' gate kernels from rnn_actor
in_keys = ['hn', 'hr', 'hz']
titles = ['hn', 'hr', 'hz']

# Collect all kernels
kernels = []
for key in in_keys:
    if key in params['params']['rnn_actor']:
        kernels.append(params['params']['rnn_actor'][key]['kernel'])

# Stack kernels along a new dimension to create (n_input, n_output, n_gates)
stacked_kernels = jnp.stack(kernels, axis=2)
n_input, n_output, n_gates = stacked_kernels.shape

# Compute similarity between output units based on their connectivity patterns
# For each output unit, we have a vector of shape (n_input * n_gates)
unit_vectors = stacked_kernels[..., 0].reshape(n_input * 1, n_output).T  # shape: (n_output, n_input * n_gates)

# Compute pairwise cosine similarity between units
similarity_matrix = jnp.zeros((n_output, n_output))
for i in range(n_output):
    for j in range(n_output):
        dot_prod = jnp.dot(unit_vectors[i], unit_vectors[j])
        norm_i = jnp.linalg.norm(unit_vectors[i])
        norm_j = jnp.linalg.norm(unit_vectors[j])
        similarity_matrix = similarity_matrix.at[i, j].set(dot_prod / (norm_i * norm_j))
        
# Convert similarity to distance for clustering
distance_matrix = 1 - similarity_matrix
distance_matrix = jnp.where(distance_matrix < 1e-4, 0, distance_matrix)


# Perform hierarchical clustering
linkage_matrix = linkage(squareform(distance_matrix), method='average')

# Get the ordering from hierarchical clustering
from scipy.cluster.hierarchy import leaves_list
cluster_order = leaves_list(linkage_matrix)

# Reorder the kernels according to clustering
reordered_kernels = [kernel[:, cluster_order][cluster_order, :] for kernel in kernels]

# Plot the reordered kernels
fig, axes = plt.subplots(3, 1, figsize=(4, 10))
axes = axes.flatten()

for idx, (kernel, title) in enumerate(zip(reordered_kernels, titles)):
    im = axes[idx].imshow(kernel, aspect='auto', cmap='RdBu_r')
    axes[idx].set_title(f'RNN actor {title} (clustered)')
    axes[idx].set_xlabel('Output dimension (clustered)')
    axes[idx].set_ylabel('Input dimension')
    plt.colorbar(im, ax=axes[idx], label='Weight value')

plt.tight_layout()
plt.show()

# Optional: Plot the similarity matrix with clustered ordering
plt.figure(figsize=(8, 7))
reordered_sim = similarity_matrix[cluster_order, :][:, cluster_order]
plt.imshow(reordered_sim, cmap='viridis', vmin=0, vmax=1)
plt.colorbar(label='Cosine Similarity')
plt.title('Unit Similarity Matrix (Clustered Order)')
plt.xlabel('Output Unit Index (clustered)')
plt.ylabel('Output Unit Index (clustered)')
plt.tight_layout()
plt.show()

# Optional: Plot dendrogram
plt.figure(figsize=(10, 4))
dendrogram(linkage_matrix, no_labels=True)
plt.title('Hierarchical Clustering Dendrogram of RNN Output Units')
plt.xlabel('Output Unit Index')
plt.ylabel('Distance (1 - cosine similarity)')
plt.tight_layout()
plt.show()

# %%
dir_path = '../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl'

# %%
from nb_analysis_tools import load_trajectory_data, parse_behavioral_data
import numpy as np
from sklearn.decomposition import PCA

traj_data = {}

for env_idx in range(15):
    traj_data_raw = load_trajectory_data(dir_path)
    traj_data_env = parse_behavioral_data(traj_data_raw[env_idx])
    for key in traj_data_env.keys():
        if key in traj_data:
            traj_data[key] = np.concatenate([traj_data[key], traj_data_env[key]], axis=0)
        else:
            traj_data[key] = traj_data_env[key]
    
pca = PCA()
pc_activities = pca.fit_transform(traj_data['actor_hidden'])
# Out:
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)
# Loading trajectory data from: ../../results/gru_exp_true_indep_pred_all_tau_seed_8000_seed_2000_2025-10-30_16:08:08.723924/trajectories_20251030_160912.pkl
# Loaded 30 episodes
# Episode length: 20000
# Observation shape: (20000, 4)
# Action shape: (20000,)

# %%
"""
Fixed Point Analysis for RNN Dynamics

This script finds and analyzes fixed points in trained RNN agents.
A fixed point h* satisfies: h* = f(h*, x) for a given input x.
"""

import jax
import jax.numpy as jnp
from jax import jit
import optax
import matplotlib.pyplot as plt
from typing import List, Tuple
from agents.a2c_rnn_flax import init_network_and_params


def rnn_step(hidden_state, input_vec, params, network):
    """
    Execute one RNN step using the actual network.
    
    Args:
        hidden_state: Current hidden state (hidden_size,)
        input_vec: Input vector (input_size,)
        params: Network parameters
        network: A2CRNNFlax network instance
    
    Returns:
        Next hidden state (hidden_size,)
    """
    # Add batch dimension for network compatibility
    h_batch = hidden_state[None, :]
    x_batch = input_vec[None, :]
    
    # Forward pass through RNN using apply with method argument
    h_next_batch = network.apply(
        params, h_batch, x_batch, 
        method=lambda module, h, x: module.rnn_actor(h, x)
    )
    
    return h_next_batch[0].squeeze()


def find_fixed_point(
    params,
    network,
    input_vec,
    h_init,
    max_steps=5000,
    learning_rate=0.01,
    tolerance=1e-6,
    verbose=False
) -> Tuple[jnp.ndarray, bool]:
    """
    Find a fixed point via gradient descent on ||h - f(h, x)||^2.
    
    Args:
        params: Network parameters
        network: A2CRNNFlax instance
        input_vec: Fixed input context
        h_init: Initial hidden state guess
        max_steps: Maximum optimization steps
        learning_rate: Adam learning rate
        tolerance: Convergence threshold
        verbose: Print progress
    
    Returns:
        (fixed_point, converged): Fixed point and convergence flag
    """
    def loss_fn(h):
        h_next = rnn_step(h, input_vec, params, network)
        return jnp.sum((h - h_next.squeeze()) ** 2)
    
    optimizer = optax.adam(learning_rate)
    opt_state = optimizer.init(h_init)
    h = h_init
    
    @jit
    def update(h, opt_state):
        loss, grads = jax.value_and_grad(loss_fn)(h)
        updates, opt_state = optimizer.update(grads, opt_state)
        h = optax.apply_updates(h, updates)
        return h, opt_state, loss
    
    for step in range(max_steps):
        h, opt_state, loss = update(h, opt_state)
        
        if verbose and step % 500 == 0:
            print(f"  Step {step:4d}, Loss: {loss:.8f}")
        
        if loss < tolerance:
            if verbose:
                print(f"  ✓ Converged at step {step} (loss: {loss:.8f})")
            return h, True
    
    if verbose:
        print(f"  ✗ Did not converge (final loss: {loss:.8f})")
    return h, False


def find_multiple_fixed_points(
    params,
    network,
    input_vec,
    n_attempts=20,
    hidden_dim=64,
    uniqueness_threshold=0.1,
    **kwargs
) -> List[jnp.ndarray]:
    """
    Search for multiple fixed points using random initializations.
    
    Args:
        params: Network parameters
        network: A2CRNNFlax instance
        input_vec: Fixed input context
        n_attempts: Number of random initializations
        hidden_dim: Hidden state dimension
        uniqueness_threshold: Distance threshold for duplicate detection
        **kwargs: Additional arguments for find_fixed_point
    
    Returns:
        List of unique fixed points found
    """
    fixed_points = []
    
    print(f"Searching for fixed points ({n_attempts} attempts)...\n")
    
    for i in range(n_attempts):
        # print(f"Attempt {i+1}/{n_attempts}")
        
        # Random initialization
        key = jax.random.PRNGKey(i)
        index = jax.random.randint(key, 1, 0, traj_data['actor_hidden'].shape[0])
        h_init = traj_data['actor_hidden'][index, :].squeeze()
        
        h_star, converged = find_fixed_point(
            params, network, input_vec, h_init, **kwargs
        )
        
        if converged:
            # Check uniqueness
            is_unique = all(
                jnp.linalg.norm(h_star - fp) >= uniqueness_threshold
                for fp in fixed_points
            )
            
            if is_unique:
                fixed_points.append(h_star)
                # print(f"  → New fixed point found! (Total: {len(fixed_points)})\n")
            else:
                pass
                # print(f"  → Duplicate (matches existing fixed point)\n")
    
    return fixed_points


def analyze_stability(fixed_points, input_vec, params, network):
    """
    Analyze stability of fixed points via eigenvalues of Jacobian.
    
    Args:
        fixed_points: List of fixed point states
        input_vec: Input context used to find fixed points
        params: Network parameters
        network: A2CRNNFlax instance
    
    Returns:
        List of dicts with stability info
    """
    print("\n" + "="*60)
    print("STABILITY ANALYSIS")
    print("="*60)
    
    results = []
    
    for i, fp in enumerate(fixed_points):
        # Compute Jacobian at fixed point
        jacobian = jax.jacfwd(lambda h: rnn_step(h, input_vec, params, network))(fp)
        eigenvalues = jnp.linalg.eigvals(jacobian)
        max_eig = jnp.max(jnp.abs(eigenvalues))
        
        is_stable = max_eig < 1.0
        stability_str = "Stable (attractor)" if is_stable else "Unstable (saddle)"
        
        result = {
            'fixed_point': fp,
            'eigenvalues': eigenvalues,
            'max_eigenvalue': max_eig,
            'is_stable': is_stable
        }
        results.append(result)
        
        print(f"\nFixed Point {i+1}:")
        print(f"  Max |eigenvalue|: {max_eig:.6f}")
        print(f"  Status: {stability_str}")
        print(f"  Norm: {jnp.linalg.norm(fp):.4f}")
    
    return results


def visualize_fixed_points(fixed_points, stability_results=None):
    """
    Visualize fixed points in 2D projection.
    
    Args:
        fixed_points: List of fixed point states
        stability_results: Optional stability analysis results
    """
    if len(fixed_points) == 0:
        print("No fixed points to visualize")
        return
    
    fp_array = jnp.array(fixed_points)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
    
    # Plot 1: First 2 dimensions
    colors = ['green' if r['is_stable'] else 'red' 
              for r in stability_results] if stability_results else None
    
    ax1.scatter(fp_array[:, 0], fp_array[:, 1], 
                s=200, c=colors or range(len(fixed_points)),
                cmap='viridis', edgecolors='black', linewidths=2,
                alpha=0.7)
    
    for i, fp in enumerate(fp_array):
        ax1.annotate(f'{i+1}', (fp[0], fp[1]), 
                    fontsize=12, ha='center', va='center')
    
    ax1.set_xlabel('Hidden Dimension 1', fontsize=12)
    ax1.set_ylabel('Hidden Dimension 2', fontsize=12)
    ax1.set_title('Fixed Points (First 2 Dimensions)', fontsize=14)
    ax1.grid(True, alpha=0.3)
    ax1.axhline(y=0, color='k', linewidth=0.5)
    ax1.axvline(x=0, color='k', linewidth=0.5)
    
    # Plot 2: Eigenvalue spectrum
    if stability_results:
        for i, result in enumerate(stability_results):
            eigs = result['eigenvalues']
            color = 'green' if result['is_stable'] else 'red'
            ax2.scatter(eigs.real, eigs.imag, 
                       s=30, c=color, alpha=0.6, label=f'FP {i+1}')
        
        # Unit circle
        theta = jnp.linspace(0, 2*jnp.pi, 100)
        ax2.plot(jnp.cos(theta), jnp.sin(theta), 'k--', 
                linewidth=2, label='Unit circle', alpha=0.5)
        
        ax2.set_xlabel('Real Part', fontsize=12)
        ax2.set_ylabel('Imaginary Part', fontsize=12)
        ax2.set_title('Eigenvalue Spectrum', fontsize=14)
        ax2.grid(True, alpha=0.3)
        ax2.axhline(y=0, color='k', linewidth=0.5)
        ax2.axvline(x=0, color='k', linewidth=0.5)
        ax2.legend(fontsize=10)
        ax2.set_aspect('equal')
    
    plt.tight_layout()
    plt.show()


# ============================================================================
# MAIN USAGE EXAMPLE
# ============================================================================

def find_and_plot_fixed_points(input_vec, n_attempts=100):
    # Define input context
    # Input format: [obs(4), prev_action_onehot(2), prev_reward(1)]
    input_dim = CONFIG['obs_size'] + CONFIG['action_size'] + 1
    
    # Or try specific contexts:
    # sample_input = jnp.array([1, 0, 0, 0,  # obs (one-hot)
    #                           1, 0,         # prev_action (one-hot)
    #                           0.5,          # prev_reward
    #                           0.8])         # env_quality
    
    print(f"Input dimension: {input_dim}")
    
    # Find fixed points
    fixed_points = find_multiple_fixed_points(
        params=params,
        network=network,
        input_vec=input_vec,
        n_attempts=n_attempts,
        hidden_dim=CONFIG['hidden_size'],
        max_steps=10000,
        learning_rate=0.01,
        tolerance=1e-6,
        verbose=False
    )
    
    print(f"\n{'='*60}")
    print(f"SUMMARY: Found {len(fixed_points)} unique fixed points")
    print(f"{'='*60}")
    
    # Analyze stability
    if fixed_points:
        stability_results = analyze_stability(
            fixed_points, sample_input, params, network
        )
        
        # Visualize
        visualize_fixed_points(fixed_points, stability_results)
    else:
        print("\nNo fixed points found. Try:")
        print("  - Different input contexts")
        print("  - More random initializations")
        print("  - Different learning rates or tolerances")
    return fixed_points

# %%
from typing import Tuple


def rnn_step_batch(hidden_states, input_vec, params, network):
    """
    Execute one RNN step for a batch of hidden states.
    
    Args:
        hidden_states: Batch of hidden states (batch_size, hidden_size)
        input_vec: Input vector (input_size,) - same for all
        params: Network parameters
        network: A2CRNNFlax network instance
    
    Returns:
        Next hidden states (batch_size, hidden_size)
    """
    batch_size = hidden_states.shape[0]
    # Repeat input for batch
    x_batch = jnp.tile(input_vec[None, :], (batch_size, 1))
    
    # Forward pass through RNN
    h_next_batch = network.apply(
        params, hidden_states, x_batch, 
        method=lambda module, h, x: module.rnn_actor(h, x)
    )
    
    return h_next_batch[0].squeeze()


def find_fixed_points_batch(
    params,
    network,
    input_vec,
    h_inits,
    max_steps=5000,
    learning_rate=0.01,
    tolerance=1e-6,
    verbose=False
) -> Tuple[jnp.ndarray, jnp.ndarray]:
    """
    Find fixed points for multiple initializations in parallel.
    
    Args:
        params: Network parameters
        network: A2CRNNFlax instance
        input_vec: Fixed input context
        h_inits: Initial hidden states (batch_size, hidden_size)
        max_steps: Maximum optimization steps
        learning_rate: Adam learning rate
        tolerance: Convergence threshold
        verbose: Print progress
    
    Returns:
        (fixed_points, converged): Arrays of shape (batch_size, hidden_size) and (batch_size,)
    """
    batch_size = h_inits.shape[0]
    
    # Define loss function for a single hidden state
    def loss_fn_single(h):
        h_next = rnn_step_batch(h[None, :], input_vec, params, network).squeeze()
        return jnp.sum((h - h_next) ** 2)
    
    # Vectorize loss and gradient computation across batch
    loss_and_grad_fn = jax.vmap(jax.value_and_grad(loss_fn_single))
    
    optimizer = optax.adam(learning_rate)
    opt_state = optimizer.init(h_inits)
    h_batch = h_inits
    
    @jit
    def update(h_batch, opt_state):
        losses, grads = loss_and_grad_fn(h_batch)
        updates, opt_state = optimizer.update(grads, opt_state)
        h_batch = optax.apply_updates(h_batch, updates)
        return h_batch, opt_state, losses
    
    converged = jnp.zeros(batch_size, dtype=bool)
    
    for step in range(max_steps):
        h_batch, opt_state, losses = update(h_batch, opt_state)
        
        # Check convergence for each sample
        newly_converged = (losses < tolerance) & (~converged)
        converged = converged | newly_converged
        
        if verbose and step % 500 == 0:
            n_converged = jnp.sum(converged)
            print(f"  Step {step:4d}, Converged: {n_converged}/{batch_size}, Mean loss: {jnp.mean(losses):.8f}")
        
        if jnp.all(converged):
            if verbose:
                print(f"  ✓ All converged at step {step}")
            break
    
    if verbose:
        n_converged = jnp.sum(converged)
        print(f"  Final: {n_converged}/{batch_size} converged")
    
    return h_batch, converged


def filter_unique_fixed_points(
    fixed_points,
    converged,
    uniqueness_threshold=0.1
):
    """
    Filter out duplicate fixed points.
    
    Args:
        fixed_points: Array of fixed points (batch_size, hidden_size)
        converged: Boolean array indicating convergence (batch_size,)
        uniqueness_threshold: Distance threshold for duplicates
    
    Returns:
        Array of unique fixed points
    """
    # Only consider converged points
    fps = fixed_points[converged]
    
    if len(fps) == 0:
        return jnp.array([])
    
    unique_fps = [fps[0]]
    
    for fp in fps[1:]:
        is_unique = all(
            jnp.linalg.norm(fp - ufp) >= uniqueness_threshold
            for ufp in unique_fps
        )
        if is_unique:
            unique_fps.append(fp)
    
    return jnp.array(unique_fps)


def analyze_stability_batch(fixed_points, input_vec, params, network):
    """
    Analyze stability of fixed points via eigenvalues of Jacobian.
    
    Args:
        fixed_points: Array of fixed points (n_points, hidden_size)
        input_vec: Input context
        params: Network parameters
        network: A2CRNNFlax instance
    
    Returns:
        List of eigenvalue arrays
    """
    def compute_jacobian_eigs(fp):
        jacobian = jax.jacfwd(
            lambda h: rnn_step_batch(h[None, :], input_vec, params, network).squeeze()
        )(fp)
        return jnp.linalg.eigvals(jacobian)
    
    # Vectorize over fixed points
    all_eigenvalues = jax.vmap(compute_jacobian_eigs)(fixed_points)
    return all_eigenvalues


def plot_eigenspectra_grid(eigenvalues_list, n_plots=9):
    """
    Plot eigenspectra in a 3x3 grid.
    
    Args:
        eigenvalues_list: Array of eigenvalues (n_points, hidden_size)
        n_plots: Number of plots (default 9 for 3x3 grid)
    """
    n_fps = min(len(eigenvalues_list), n_plots)
    
    if n_fps == 0:
        print("No fixed points to plot")
        return
    
    fig, axes = plt.subplots(3, 3, figsize=(5, 5))
    axes = axes.flatten()
    
    # Unit circle
    theta = jnp.linspace(0, 2*jnp.pi, 100)
    unit_circle_x = jnp.cos(theta)
    unit_circle_y = jnp.sin(theta)
    
    for i in range(9):
        ax = axes[i]
        
        if i < n_fps:
            eigs = eigenvalues_list[i]
            max_eig = jnp.max(jnp.abs(eigs))
            is_stable = max_eig < 1.0
            color = 'green' if is_stable else 'red'
            
            # Plot eigenvalues
            ax.scatter(eigs.real, eigs.imag, s=30, c=color, alpha=0.6)
            
            # Plot unit circle
            ax.plot(unit_circle_x, unit_circle_y, 'k--', linewidth=1, alpha=0.5)
            
            ax.set_aspect('equal')
            ax.set_xlabel('Real')
            ax.set_ylabel('Imag')
        else:
            ax.axis('off')
    
    plt.tight_layout()
    format_plot(axes)
    plt.show()


# ============================================================================
# MAIN USAGE
# ============================================================================

def find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=100):
    """
    Find fixed points and plot their eigenspectra.
    
    Args:
        input_vec: Input context vector
        traj_data: Dictionary with 'actor_hidden' trajectory data
        params: Network parameters
        network: Network instance
        CONFIG: Config dictionary with 'hidden_size'
        n_attempts: Number of random initializations
    """
    print(f"Searching for fixed points ({n_attempts} attempts)...\n")
    
    # Create batch of random initializations from trajectory
    key = jax.random.PRNGKey(42)
    indices = jax.random.randint(key, (n_attempts,), 0, traj_data['actor_hidden'].shape[0])
    h_inits = traj_data['actor_hidden'][indices, :]
    
    # Find fixed points in batch
    fixed_points, converged = find_fixed_points_batch(
        params=params,
        network=network,
        input_vec=input_vec,
        h_inits=h_inits,
        max_steps=60000,
        learning_rate=0.001,
        tolerance=5e-8,
        verbose=True
    )
    
    # Filter unique fixed points
    unique_fps = filter_unique_fixed_points(
        fixed_points, converged, uniqueness_threshold=0.1
    )
    
    print(f"\n{'='*60}")
    print(f"SUMMARY: Found {len(unique_fps)} unique fixed points")
    print(f"{'='*60}\n")
    
    if len(unique_fps) > 0:
        # Analyze stability
        eigenvalues = analyze_stability_batch(unique_fps, input_vec, params, network)
        
        # Plot first 9 eigenspectra
        plot_eigenspectra_grid(eigenvalues, n_plots=9)
    else:
        print("No fixed points found.")

    return fixed_points[converged,:]


def run_states_forward(
    h_inits,
    input_vec,
    params,
    network,
    n_steps=100
):
    """
    Run multiple initial hidden states forward through the RNN.
    
    Args:
        h_inits: Initial hidden states (batch_size, hidden_size)
        input_vec: Fixed input context (input_size,)
        params: Network parameters
        network: A2CRNNFlax instance
        n_steps: Number of forward steps to simulate
    
    Returns:
        trajectories: Array of shape (n_steps, batch_size, hidden_size)
    """
    batch_size = h_inits.shape[0]
    hidden_size = h_inits.shape[1]
    
    # Initialize trajectory storage
    trajectories = jnp.zeros((n_steps, batch_size, hidden_size))
    trajectories = trajectories.at[0].set(h_inits)
    
    # Run forward
    h_current = h_inits
    for t in range(1, n_steps):
        h_current = rnn_step_batch(h_current, input_vec, params, network)
        trajectories = trajectories.at[t].set(h_current)
    
    return trajectories

# %%
from matplotlib.collections import LineCollection
from matplotlib.colors import Normalize
from aux_funcs import format_plot, format_pc_plot

def plot_trajectory(fixed_points, start=100, end=150):
    scale = 1.2
    fig, axs = plt.subplots(2, 2, figsize=(4.3 * scale, 4 * scale))

    # define a colormap and normalization for time
    cmap = plt.cm.viridis
    norm = Normalize(vmin=0, vmax=end-start)

    for k in np.arange(0, 8, 2):
        k_x, k_y = int(k/4), int(k/2) % 2

        cbar = axs[k_x, k_y].scatter(
            pc_activities.T[k, :],
            pc_activities.T[k+1, :],
            s=0.1,
            color='#d7d9d7',
            alpha=1,
        )

        for fp in pca.transform(fixed_points):
            axs[k_x, k_y].scatter(
                fp[k],
                fp[k+1],
                s=5,
                color='red',
            )

    fig.tight_layout()
    format_pc_plot(axs)

# %%
# Configuration
CONFIG = {
    'hidden_size': 64,
    'action_size': 2,
    'obs_size': 4,
    'rnn_type': 'GRU',  # or 'VANILLA'
    'var_noise': 0.0,
}

# Define input context
# Input format: [obs(4), prev_action_onehot(2), prev_reward(1)]
input_dim = CONFIG['obs_size'] + CONFIG['action_size'] + 1

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[5].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=500)
print(fixed_points.shape)
plot_trajectory(fixed_points, 0, 2000)
# Out:
# Searching for fixed points (500 attempts)...
#
#   Step    0, Converged: 0/500, Mean loss: 2.80097628
#   Step  500, Converged: 0/500, Mean loss: 0.12907960
#   Step 1000, Converged: 0/500, Mean loss: 0.04284348
#   Step 1500, Converged: 0/500, Mean loss: 0.02290002
#   Step 2000, Converged: 0/500, Mean loss: 0.01451040
#   Step 2500, Converged: 0/500, Mean loss: 0.01004268
#   Step 3000, Converged: 0/500, Mean loss: 0.00731899
#   Step 3500, Converged: 0/500, Mean loss: 0.00550766
#   Step 4000, Converged: 0/500, Mean loss: 0.00422399
#   Step 4500, Converged: 0/500, Mean loss: 0.00327975
#   Step 5000, Converged: 0/500, Mean loss: 0.00256419
#   Step 5500, Converged: 0/500, Mean loss: 0.00201134
#   Step 6000, Converged: 0/500, Mean loss: 0.00157828
#   Step 6500, Converged: 2/500, Mean loss: 0.00123908
#   Step 7000, Converged: 3/500, Mean loss: 0.00097337
#   Step 7500, Converged: 3/500, Mean loss: 0.00076562
#   Step 8000, Converged: 3/500, Mean loss: 0.00060303
#   Step 8500, Converged: 3/500, Mean loss: 0.00047527
#   Step 9000, Converged: 4/500, Mean loss: 0.00037377
#   Step 9500, Converged: 4/500, Mean loss: 0.00029171
#   Step 10000, Converged: 4/500, Mean loss: 0.00022542
#   Step 10500, Converged: 4/500, Mean loss: 0.00017313
#   Step 11000, Converged: 4/500, Mean loss: 0.00013253
#   Step 11500, Converged: 4/500, Mean loss: 0.00010118
#   Step 12000, Converged: 5/500, Mean loss: 0.00007714
#   Step 12500, Converged: 6/500, Mean loss: 0.00005910
#   Step 13000, Converged: 6/500, Mean loss: 0.00004564
#   Step 13500, Converged: 6/500, Mean loss: 0.00003556
#   Step 14000, Converged: 6/500, Mean loss: 0.00002791
#   Step 14500, Converged: 6/500, Mean loss: 0.00002216
#   Step 15000, Converged: 7/500, Mean loss: 0.00001781
#   Step 15500, Converged: 7/500, Mean loss: 0.00001448
#   Step 16000, Converged: 8/500, Mean loss: 0.00001195
#   Step 16500, Converged: 8/500, Mean loss: 0.00001000
#   Step 17000, Converged: 9/500, Mean loss: 0.00000850
#   Step 17500, Converged: 10/500, Mean loss: 0.00000732
#   Step 18000, Converged: 12/500, Mean loss: 0.00000639
#   Step 18500, Converged: 12/500, Mean loss: 0.00000561
#   Step 19000, Converged: 12/500, Mean loss: 0.00000502
#   Step 19500, Converged: 12/500, Mean loss: 0.00000455
#   Step 20000, Converged: 12/500, Mean loss: 0.00000413
#   Step 20500, Converged: 12/500, Mean loss: 0.00000378
#   Step 21000, Converged: 12/500, Mean loss: 0.00000349
#   Step 21500, Converged: 13/500, Mean loss: 0.00000322
#   Step 22000, Converged: 13/500, Mean loss: 0.00000302
#   Step 22500, Converged: 13/500, Mean loss: 0.00000281
#   Step 23000, Converged: 14/500, Mean loss: 0.00000267
#   Step 23500, Converged: 14/500, Mean loss: 0.00000250
#   Step 24000, Converged: 14/500, Mean loss: 0.00000237
#   Step 24500, Converged: 14/500, Mean loss: 0.00000226
#   Step 25000, Converged: 15/500, Mean loss: 0.00000214
#   Step 25500, Converged: 16/500, Mean loss: 0.00000207
#   Step 26000, Converged: 17/500, Mean loss: 0.00000194
#   Step 26500, Converged: 18/500, Mean loss: 0.00000188
#   Step 27000, Converged: 19/500, Mean loss: 0.00000180
#   Step 27500, Converged: 21/500, Mean loss: 0.00000176
#   Step 28000, Converged: 22/500, Mean loss: 0.00000168
#   Step 28500, Converged: 23/500, Mean loss: 0.00000163
#   Step 29000, Converged: 26/500, Mean loss: 0.00000157
#   Step 29500, Converged: 27/500, Mean loss: 0.00000154
#   Step 30000, Converged: 27/500, Mean loss: 0.00000147
#   Step 30500, Converged: 27/500, Mean loss: 0.00000145
#   Step 31000, Converged: 28/500, Mean loss: 0.00000139
#   Step 31500, Converged: 29/500, Mean loss: 0.00000136
#   Step 32000, Converged: 29/500, Mean loss: 0.00000134
#   Step 32500, Converged: 29/500, Mean loss: 0.00000130
#   Step 33000, Converged: 29/500, Mean loss: 0.00000126
#   Step 33500, Converged: 29/500, Mean loss: 0.00000122
#   Step 34000, Converged: 30/500, Mean loss: 0.00000120
#   Step 34500, Converged: 32/500, Mean loss: 0.00000116
#   Step 35000, Converged: 34/500, Mean loss: 0.00000115
#   Step 35500, Converged: 34/500, Mean loss: 0.00000114
#   Step 36000, Converged: 36/500, Mean loss: 0.00000112
#   Step 36500, Converged: 36/500, Mean loss: 0.00000109
#   Step 37000, Converged: 36/500, Mean loss: 0.00000106
#   Step 37500, Converged: 38/500, Mean loss: 0.00000106
#   Step 38000, Converged: 40/500, Mean loss: 0.00000104
#   Step 38500, Converged: 40/500, Mean loss: 0.00000103
#   Step 39000, Converged: 40/500, Mean loss: 0.00000099
#   Step 39500, Converged: 40/500, Mean loss: 0.00000097
#   Step 40000, Converged: 42/500, Mean loss: 0.00000096
#   Step 40500, Converged: 45/500, Mean loss: 0.00000094
#   Step 41000, Converged: 45/500, Mean loss: 0.00000092
#   Step 41500, Converged: 46/500, Mean loss: 0.00000093
#   Step 42000, Converged: 46/500, Mean loss: 0.00000090
#   Step 42500, Converged: 46/500, Mean loss: 0.00000088
#   Step 43000, Converged: 46/500, Mean loss: 0.00000088
#   Step 43500, Converged: 46/500, Mean loss: 0.00000087
#   Step 44000, Converged: 46/500, Mean loss: 0.00000088
#   Step 44500, Converged: 46/500, Mean loss: 0.00000086
#   Step 45000, Converged: 46/500, Mean loss: 0.00000083
#   Step 45500, Converged: 48/500, Mean loss: 0.00000082
#   Step 46000, Converged: 48/500, Mean loss: 0.00000083
#   Step 46500, Converged: 49/500, Mean loss: 0.00000080
#   Step 47000, Converged: 50/500, Mean loss: 0.00000080
#   Step 47500, Converged: 51/500, Mean loss: 0.00000080
#   Step 48000, Converged: 51/500, Mean loss: 0.00000080
#   Step 48500, Converged: 51/500, Mean loss: 0.00000076
#   Step 49000, Converged: 54/500, Mean loss: 0.00000075
#   Step 49500, Converged: 55/500, Mean loss: 0.00000074
#   Step 50000, Converged: 55/500, Mean loss: 0.00000073
#   Step 50500, Converged: 57/500, Mean loss: 0.00000073
#   Step 51000, Converged: 58/500, Mean loss: 0.00000074
#   Step 51500, Converged: 60/500, Mean loss: 0.00000070
#   Step 52000, Converged: 62/500, Mean loss: 0.00000071
#   Step 52500, Converged: 62/500, Mean loss: 0.00000071
#   Step 53000, Converged: 63/500, Mean loss: 0.00000070
#   Step 53500, Converged: 66/500, Mean loss: 0.00000069
#   Step 54000, Converged: 68/500, Mean loss: 0.00000069
#   Step 54500, Converged: 68/500, Mean loss: 0.00000068
#   Step 55000, Converged: 69/500, Mean loss: 0.00000069
#   Step 55500, Converged: 70/500, Mean loss: 0.00000066
#   Step 56000, Converged: 70/500, Mean loss: 0.00000070
#   Step 56500, Converged: 70/500, Mean loss: 0.00000066
#   Step 57000, Converged: 70/500, Mean loss: 0.00000066
#   Step 57500, Converged: 70/500, Mean loss: 0.00000067
#   Step 58000, Converged: 70/500, Mean loss: 0.00000066
#   Step 58500, Converged: 72/500, Mean loss: 0.00000065
#   Step 59000, Converged: 72/500, Mean loss: 0.00000062
#   Step 59500, Converged: 74/500, Mean loss: 0.00000061
#   Final: 75/500 converged
#
# ============================================================
# SUMMARY: Found 75 unique fixed points
# ============================================================
# (75, 64)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[5].set(1)

key = jax.random.PRNGKey(42)
indices = jax.random.randint(key, (200,), 0, traj_data['actor_hidden'].shape[0])
h_inits = traj_data['actor_hidden'][indices, :]

trajectories = run_states_forward(
    h_inits,
    input_vec,
    params,
    network,
    n_steps=500
)

print(trajectories.shape)

plot_trajectory(trajectories[:, -1, :])
# Out:
# (500, 200, 64)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[5].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=500)
print(fixed_points.shape)
plot_trajectory(0, 2000)
# Out:
# Searching for fixed points (500 attempts)...
#
#   Step    0, Converged: 0/500, Mean loss: 1.71101034
#   Step  500, Converged: 0/500, Mean loss: 0.06447528
#   Step 1000, Converged: 0/500, Mean loss: 0.01971688
#   Step 1500, Converged: 0/500, Mean loss: 0.01016336
#   Step 2000, Converged: 0/500, Mean loss: 0.00621403
#   Step 2500, Converged: 0/500, Mean loss: 0.00411705
#   Step 3000, Converged: 0/500, Mean loss: 0.00285823
#   Step 3500, Converged: 0/500, Mean loss: 0.00204891
#   Step 4000, Converged: 0/500, Mean loss: 0.00150667
#   Step 4500, Converged: 0/500, Mean loss: 0.00113061
#   Step 5000, Converged: 0/500, Mean loss: 0.00086295
#   Step 5500, Converged: 0/500, Mean loss: 0.00066838
#   Step 6000, Converged: 0/500, Mean loss: 0.00052410
#   Step 6500, Converged: 1/500, Mean loss: 0.00041484
#   Step 7000, Converged: 1/500, Mean loss: 0.00033045
#   Step 7500, Converged: 1/500, Mean loss: 0.00026428
#   Step 8000, Converged: 1/500, Mean loss: 0.00021187
#   Step 8500, Converged: 1/500, Mean loss: 0.00017013
#   Step 9000, Converged: 1/500, Mean loss: 0.00013692
#   Step 9500, Converged: 1/500, Mean loss: 0.00011053
#   Step 10000, Converged: 2/500, Mean loss: 0.00008955
#   Step 10500, Converged: 2/500, Mean loss: 0.00007292
#   Step 11000, Converged: 2/500, Mean loss: 0.00005975
#   Step 11500, Converged: 2/500, Mean loss: 0.00004933
#   Step 12000, Converged: 2/500, Mean loss: 0.00004097
#   Step 12500, Converged: 2/500, Mean loss: 0.00003420
#   Step 13000, Converged: 3/500, Mean loss: 0.00002867
#   Step 13500, Converged: 4/500, Mean loss: 0.00002415
#   Step 14000, Converged: 4/500, Mean loss: 0.00002042
#   Step 14500, Converged: 4/500, Mean loss: 0.00001741
#   Step 15000, Converged: 4/500, Mean loss: 0.00001499
#   Step 15500, Converged: 4/500, Mean loss: 0.00001299
#   Step 16000, Converged: 4/500, Mean loss: 0.00001143
#   Step 16500, Converged: 4/500, Mean loss: 0.00001012
#   Step 17000, Converged: 4/500, Mean loss: 0.00000906
#   Step 17500, Converged: 4/500, Mean loss: 0.00000823
#   Step 18000, Converged: 4/500, Mean loss: 0.00000753
#   Step 18500, Converged: 4/500, Mean loss: 0.00000690
#   Step 19000, Converged: 4/500, Mean loss: 0.00000638
#   Step 19500, Converged: 5/500, Mean loss: 0.00000600
#   Step 20000, Converged: 5/500, Mean loss: 0.00000558
#   Step 20500, Converged: 5/500, Mean loss: 0.00000527
#   Step 21000, Converged: 5/500, Mean loss: 0.00000498
#   Step 21500, Converged: 5/500, Mean loss: 0.00000472
#   Step 22000, Converged: 5/500, Mean loss: 0.00000448
#   Step 22500, Converged: 5/500, Mean loss: 0.00000429
#   Step 23000, Converged: 5/500, Mean loss: 0.00000410
#   Step 23500, Converged: 5/500, Mean loss: 0.00000391
#   Step 24000, Converged: 5/500, Mean loss: 0.00000374
#   Step 24500, Converged: 5/500, Mean loss: 0.00000366
#   Step 25000, Converged: 6/500, Mean loss: 0.00000347
#   Step 25500, Converged: 6/500, Mean loss: 0.00000337
#   Step 26000, Converged: 6/500, Mean loss: 0.00000326
#   Step 26500, Converged: 6/500, Mean loss: 0.00000315
#   Step 27000, Converged: 6/500, Mean loss: 0.00000306
#   Step 27500, Converged: 6/500, Mean loss: 0.00000297
#   Step 28000, Converged: 8/500, Mean loss: 0.00000294
#   Step 28500, Converged: 8/500, Mean loss: 0.00000281
#   Step 29000, Converged: 9/500, Mean loss: 0.00000274
#   Step 29500, Converged: 9/500, Mean loss: 0.00000271
#   Step 30000, Converged: 10/500, Mean loss: 0.00000261
#   Step 30500, Converged: 10/500, Mean loss: 0.00000252
#   Step 31000, Converged: 10/500, Mean loss: 0.00000249
#   Step 31500, Converged: 10/500, Mean loss: 0.00000239
#   Step 32000, Converged: 10/500, Mean loss: 0.00000240
#   Step 32500, Converged: 10/500, Mean loss: 0.00000232
#   Step 33000, Converged: 10/500, Mean loss: 0.00000227
#   Step 33500, Converged: 10/500, Mean loss: 0.00000224
#   Step 34000, Converged: 10/500, Mean loss: 0.00000218
#   Step 34500, Converged: 12/500, Mean loss: 0.00000217
#   Step 35000, Converged: 12/500, Mean loss: 0.00000211
#   Step 35500, Converged: 12/500, Mean loss: 0.00000207
#   Step 36000, Converged: 12/500, Mean loss: 0.00000204
#   Step 36500, Converged: 12/500, Mean loss: 0.00000199
#   Step 37000, Converged: 13/500, Mean loss: 0.00000199
#   Step 37500, Converged: 13/500, Mean loss: 0.00000195
#   Step 38000, Converged: 13/500, Mean loss: 0.00000194
#   Step 38500, Converged: 13/500, Mean loss: 0.00000188
#   Step 39000, Converged: 13/500, Mean loss: 0.00000186
#   Step 39500, Converged: 13/500, Mean loss: 0.00000184
#   Step 40000, Converged: 13/500, Mean loss: 0.00000180
#   Step 40500, Converged: 14/500, Mean loss: 0.00000177
#   Step 41000, Converged: 15/500, Mean loss: 0.00000173
#   Step 41500, Converged: 15/500, Mean loss: 0.00000170
#   Step 42000, Converged: 15/500, Mean loss: 0.00000170
#   Step 42500, Converged: 15/500, Mean loss: 0.00000167
#   Step 43000, Converged: 15/500, Mean loss: 0.00000166
#   Step 43500, Converged: 15/500, Mean loss: 0.00000165
#   Step 44000, Converged: 15/500, Mean loss: 0.00000162
#   Step 44500, Converged: 17/500, Mean loss: 0.00000156
#   Step 45000, Converged: 17/500, Mean loss: 0.00000156
#   Step 45500, Converged: 17/500, Mean loss: 0.00000152
#   Step 46000, Converged: 17/500, Mean loss: 0.00000153
#   Step 46500, Converged: 17/500, Mean loss: 0.00000147
#   Step 47000, Converged: 17/500, Mean loss: 0.00000150
#   Step 47500, Converged: 17/500, Mean loss: 0.00000149
#   Step 48000, Converged: 18/500, Mean loss: 0.00000146
#   Step 48500, Converged: 18/500, Mean loss: 0.00000145
#   Step 49000, Converged: 18/500, Mean loss: 0.00000143
#   Step 49500, Converged: 18/500, Mean loss: 0.00000142
#   Step 50000, Converged: 18/500, Mean loss: 0.00000142
#   Step 50500, Converged: 18/500, Mean loss: 0.00000138
#   Step 51000, Converged: 19/500, Mean loss: 0.00000136
#   Step 51500, Converged: 19/500, Mean loss: 0.00000135
#   Step 52000, Converged: 19/500, Mean loss: 0.00000134
#   Step 52500, Converged: 19/500, Mean loss: 0.00000135
#   Step 53000, Converged: 20/500, Mean loss: 0.00000135
#   Step 53500, Converged: 20/500, Mean loss: 0.00000128
#   Step 54000, Converged: 20/500, Mean loss: 0.00000128
#   Step 54500, Converged: 21/500, Mean loss: 0.00000126
#   Step 55000, Converged: 21/500, Mean loss: 0.00000126
#   Step 55500, Converged: 22/500, Mean loss: 0.00000128
#   Step 56000, Converged: 22/500, Mean loss: 0.00000127
#   Step 56500, Converged: 22/500, Mean loss: 0.00000123
#   Step 57000, Converged: 22/500, Mean loss: 0.00000123
#   Step 57500, Converged: 22/500, Mean loss: 0.00000119
#   Step 58000, Converged: 22/500, Mean loss: 0.00000123
#   Step 58500, Converged: 22/500, Mean loss: 0.00000120
#   Step 59000, Converged: 22/500, Mean loss: 0.00000119
#   Step 59500, Converged: 22/500, Mean loss: 0.00000116
#   Final: 22/500 converged
#
# ============================================================
# SUMMARY: Found 22 unique fixed points
# ============================================================
# (22, 64)
# [-0.17813528  0.53483266  0.00330297 -0.1272605  -1.991728   -0.05258045
#  -0.1219815  -0.06764346]

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[5].set(1)

key = jax.random.PRNGKey(42)
indices = jax.random.randint(key, (200,), 0, traj_data['actor_hidden'].shape[0])
h_inits = traj_data['actor_hidden'][indices, :]

trajectories = run_states_forward(
    h_inits,
    input_vec,
    params,
    network,
    n_steps=500
)

print(trajectories.shape)

plot_trajectory(trajectories[:, -1, :])
# Out:
# (500, 200, 64)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[1].set(1)
input_vec = input_vec.at[5].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=500)
print(fixed_points.shape)
plot_trajectory(0, 2000)
# Out:
# Searching for fixed points (500 attempts)...
#
#   Step    0, Converged: 0/500, Mean loss: 1.68947303
#   Step  500, Converged: 0/500, Mean loss: 0.06450813
#   Step 1000, Converged: 0/500, Mean loss: 0.01998556
#   Step 1500, Converged: 0/500, Mean loss: 0.00903786
#   Step 2000, Converged: 0/500, Mean loss: 0.00481882
#   Step 2500, Converged: 0/500, Mean loss: 0.00285869
#   Step 3000, Converged: 0/500, Mean loss: 0.00183387
#   Step 3500, Converged: 0/500, Mean loss: 0.00124507
#   Step 4000, Converged: 0/500, Mean loss: 0.00087889
#   Step 4500, Converged: 0/500, Mean loss: 0.00063773
#   Step 5000, Converged: 0/500, Mean loss: 0.00047237
#   Step 5500, Converged: 0/500, Mean loss: 0.00035643
#   Step 6000, Converged: 0/500, Mean loss: 0.00027344
#   Step 6500, Converged: 0/500, Mean loss: 0.00021254
#   Step 7000, Converged: 0/500, Mean loss: 0.00016678
#   Step 7500, Converged: 0/500, Mean loss: 0.00013177
#   Step 8000, Converged: 0/500, Mean loss: 0.00010464
#   Step 8500, Converged: 0/500, Mean loss: 0.00008355
#   Step 9000, Converged: 0/500, Mean loss: 0.00006718
#   Step 9500, Converged: 0/500, Mean loss: 0.00005443
#   Step 10000, Converged: 0/500, Mean loss: 0.00004440
#   Step 10500, Converged: 0/500, Mean loss: 0.00003649
#   Step 11000, Converged: 0/500, Mean loss: 0.00003020
#   Step 11500, Converged: 0/500, Mean loss: 0.00002518
#   Step 12000, Converged: 0/500, Mean loss: 0.00002124
#   Step 12500, Converged: 0/500, Mean loss: 0.00001808
#   Step 13000, Converged: 0/500, Mean loss: 0.00001556
#   Step 13500, Converged: 0/500, Mean loss: 0.00001358
#   Step 14000, Converged: 0/500, Mean loss: 0.00001206
#   Step 14500, Converged: 0/500, Mean loss: 0.00001069
#   Step 15000, Converged: 0/500, Mean loss: 0.00000959
#   Step 15500, Converged: 0/500, Mean loss: 0.00000878
#   Step 16000, Converged: 0/500, Mean loss: 0.00000802
#   Step 16500, Converged: 0/500, Mean loss: 0.00000743
#   Step 17000, Converged: 0/500, Mean loss: 0.00000683
#   Step 17500, Converged: 0/500, Mean loss: 0.00000641
#   Step 18000, Converged: 0/500, Mean loss: 0.00000600
#   Step 18500, Converged: 0/500, Mean loss: 0.00000570
#   Step 19000, Converged: 0/500, Mean loss: 0.00000543
#   Step 19500, Converged: 0/500, Mean loss: 0.00000518
#   Step 20000, Converged: 0/500, Mean loss: 0.00000484
#   Step 20500, Converged: 0/500, Mean loss: 0.00000467
#   Step 21000, Converged: 0/500, Mean loss: 0.00000451
#   Step 21500, Converged: 0/500, Mean loss: 0.00000435
#   Step 22000, Converged: 0/500, Mean loss: 0.00000415
#   Step 22500, Converged: 0/500, Mean loss: 0.00000407
#   Step 23000, Converged: 0/500, Mean loss: 0.00000387
#   Step 23500, Converged: 0/500, Mean loss: 0.00000371
#   Step 24000, Converged: 0/500, Mean loss: 0.00000358
#   Step 24500, Converged: 0/500, Mean loss: 0.00000345
#   Step 25000, Converged: 0/500, Mean loss: 0.00000338
#   Step 25500, Converged: 0/500, Mean loss: 0.00000326
#   Step 26000, Converged: 0/500, Mean loss: 0.00000313
#   Step 26500, Converged: 0/500, Mean loss: 0.00000314
#   Step 27000, Converged: 0/500, Mean loss: 0.00000302
#   Step 27500, Converged: 0/500, Mean loss: 0.00000291
#   Step 28000, Converged: 0/500, Mean loss: 0.00000285
#   Step 28500, Converged: 0/500, Mean loss: 0.00000276
#   Step 29000, Converged: 0/500, Mean loss: 0.00000283
#   Step 29500, Converged: 0/500, Mean loss: 0.00000262
#   Step 30000, Converged: 0/500, Mean loss: 0.00000261
#   Step 30500, Converged: 0/500, Mean loss: 0.00000255
#   Step 31000, Converged: 0/500, Mean loss: 0.00000256
#   Step 31500, Converged: 0/500, Mean loss: 0.00000251
#   Step 32000, Converged: 0/500, Mean loss: 0.00000244
#   Step 32500, Converged: 0/500, Mean loss: 0.00000240
#   Step 33000, Converged: 0/500, Mean loss: 0.00000234
#   Step 33500, Converged: 0/500, Mean loss: 0.00000230
#   Step 34000, Converged: 0/500, Mean loss: 0.00000224
#   Step 34500, Converged: 0/500, Mean loss: 0.00000225
#   Step 35000, Converged: 0/500, Mean loss: 0.00000218
#   Step 35500, Converged: 0/500, Mean loss: 0.00000216
#   Step 36000, Converged: 0/500, Mean loss: 0.00000213
#   Step 36500, Converged: 0/500, Mean loss: 0.00000209
#   Step 37000, Converged: 0/500, Mean loss: 0.00000211
#   Step 37500, Converged: 0/500, Mean loss: 0.00000206
#   Step 38000, Converged: 0/500, Mean loss: 0.00000200
#   Step 38500, Converged: 0/500, Mean loss: 0.00000194
#   Step 39000, Converged: 0/500, Mean loss: 0.00000194
#   Step 39500, Converged: 0/500, Mean loss: 0.00000195
#   Step 40000, Converged: 0/500, Mean loss: 0.00000194
#   Step 40500, Converged: 0/500, Mean loss: 0.00000192
#   Step 41000, Converged: 0/500, Mean loss: 0.00000186
#   Step 41500, Converged: 0/500, Mean loss: 0.00000185
#   Step 42000, Converged: 0/500, Mean loss: 0.00000182
#   Step 42500, Converged: 0/500, Mean loss: 0.00000181
#   Step 43000, Converged: 0/500, Mean loss: 0.00000180
#   Step 43500, Converged: 0/500, Mean loss: 0.00000172
#   Step 44000, Converged: 0/500, Mean loss: 0.00000177
#   Step 44500, Converged: 0/500, Mean loss: 0.00000173
#   Step 45000, Converged: 0/500, Mean loss: 0.00000170
#   Step 45500, Converged: 0/500, Mean loss: 0.00000165
#   Step 46000, Converged: 0/500, Mean loss: 0.00000171
#   Step 46500, Converged: 0/500, Mean loss: 0.00000172
#   Step 47000, Converged: 0/500, Mean loss: 0.00000168
#   Step 47500, Converged: 0/500, Mean loss: 0.00000165
#   Step 48000, Converged: 0/500, Mean loss: 0.00000165
#   Step 48500, Converged: 0/500, Mean loss: 0.00000165
#   Step 49000, Converged: 0/500, Mean loss: 0.00000162
#   Step 49500, Converged: 0/500, Mean loss: 0.00000160
#   Step 50000, Converged: 0/500, Mean loss: 0.00000169
#   Step 50500, Converged: 0/500, Mean loss: 0.00000156
#   Step 51000, Converged: 0/500, Mean loss: 0.00000156
#   Step 51500, Converged: 0/500, Mean loss: 0.00000151
#   Step 52000, Converged: 0/500, Mean loss: 0.00000165
#   Step 52500, Converged: 0/500, Mean loss: 0.00000157
#   Step 53000, Converged: 0/500, Mean loss: 0.00000148
#   Step 53500, Converged: 0/500, Mean loss: 0.00000148
#   Step 54000, Converged: 0/500, Mean loss: 0.00000154
#   Step 54500, Converged: 0/500, Mean loss: 0.00000151
#   Step 55000, Converged: 0/500, Mean loss: 0.00000153
#   Step 55500, Converged: 0/500, Mean loss: 0.00000147
#   Step 56000, Converged: 0/500, Mean loss: 0.00000149
#   Step 56500, Converged: 0/500, Mean loss: 0.00000148
#   Step 57000, Converged: 0/500, Mean loss: 0.00000149
#   Step 57500, Converged: 0/500, Mean loss: 0.00000144
#   Step 58000, Converged: 0/500, Mean loss: 0.00000144
#   Step 58500, Converged: 0/500, Mean loss: 0.00000137
#   Step 59000, Converged: 0/500, Mean loss: 0.00000147
#   Step 59500, Converged: 0/500, Mean loss: 0.00000135
#   Final: 0/500 converged
#
# ============================================================
# SUMMARY: Found 0 unique fixed points
# ============================================================
#
# No fixed points found.
# (0, 64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[314], line 9
#       7 fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=500)
#       8 print(fixed_points.shape)
# ----> 9 plot_trajectory(0, 2000)
#
# Cell In[310], line 13, in plot_trajectory(start, end)
#      10 cmap = plt.cm.viridis
#      11 norm = Normalize(vmin=0, vmax=end-start)
# ---> 13 print(pca.transform(fixed_points)[0, :8])
#      15 for k in np.arange(0, 8, 2):
#      16     k_x, k_y = int(k/4), int(k/2) % 2
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/decomposition/_base.py:138, in _BasePCA.transform(self, X)
#     134 xp, _ = get_namespace(X, self.components_, self.explained_variance_)
#     136 check_is_fitted(self)
# --> 138 X = validate_data(
#     139     self,
#     140     X,
#     141     dtype=[xp.float64, xp.float32],
#     142     accept_sparse=("csr", "csc"),
#     143     reset=False,
#     144 )
#     145 return self._transform(X, xp=xp, x_is_centered=False)
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/validation.py:1130, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1128     n_samples = _num_samples(array)
#    1129     if n_samples < ensure_min_samples:
# -> 1130         raise ValueError(
#    1131             "Found array with %d sample(s) (shape=%s) while a"
#    1132             " minimum of %d is required%s."
#    1133             % (n_samples, array.shape, ensure_min_samples, context)
#    1134         )
#    1136 if ensure_min_features > 0 and array.ndim == 2:
#    1137     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 64)) while a minimum of 1 is required by PCA.

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[1].set(1)
input_vec = input_vec.at[5].set(1)

key = jax.random.PRNGKey(42)
indices = jax.random.randint(key, (200,), 0, traj_data['actor_hidden'].shape[0])
h_inits = traj_data['actor_hidden'][indices, :]

trajectories = run_states_forward(
    h_inits,
    input_vec,
    params,
    network,
    n_steps=500
)

print(trajectories.shape)

plot_trajectory(trajectories[:, -1, :])
# Out:
# (500, 200, 64)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[1].set(1)
input_vec = input_vec.at[4].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=500)
print(fixed_points.shape)
plot_trajectory(0, 2000)
# Out:
# Searching for fixed points (500 attempts)...
#
#   Step    0, Converged: 0/500, Mean loss: 2.75672174
#   Step  500, Converged: 0/500, Mean loss: 0.09103947
#   Step 1000, Converged: 0/500, Mean loss: 0.01760113
#   Step 1500, Converged: 0/500, Mean loss: 0.00753176
#   Step 2000, Converged: 0/500, Mean loss: 0.00443373
#   Step 2500, Converged: 0/500, Mean loss: 0.00293883
#   Step 3000, Converged: 0/500, Mean loss: 0.00205472
#   Step 3500, Converged: 0/500, Mean loss: 0.00147923
#   Step 4000, Converged: 0/500, Mean loss: 0.00108226
#   Step 4500, Converged: 0/500, Mean loss: 0.00079742
#   Step 5000, Converged: 0/500, Mean loss: 0.00058861
#   Step 5500, Converged: 0/500, Mean loss: 0.00043445
#   Step 6000, Converged: 0/500, Mean loss: 0.00032068
#   Step 6500, Converged: 0/500, Mean loss: 0.00023715
#   Step 7000, Converged: 0/500, Mean loss: 0.00017638
#   Step 7500, Converged: 0/500, Mean loss: 0.00013250
#   Step 8000, Converged: 0/500, Mean loss: 0.00010085
#   Step 8500, Converged: 0/500, Mean loss: 0.00007800
#   Step 9000, Converged: 0/500, Mean loss: 0.00006137
#   Step 9500, Converged: 0/500, Mean loss: 0.00004916
#   Step 10000, Converged: 0/500, Mean loss: 0.00004001
#   Step 10500, Converged: 0/500, Mean loss: 0.00003321
#   Step 11000, Converged: 0/500, Mean loss: 0.00002799
#   Step 11500, Converged: 0/500, Mean loss: 0.00002407
#   Step 12000, Converged: 0/500, Mean loss: 0.00002103
#   Step 12500, Converged: 0/500, Mean loss: 0.00001873
#   Step 13000, Converged: 0/500, Mean loss: 0.00001693
#   Step 13500, Converged: 0/500, Mean loss: 0.00001547
#   Step 14000, Converged: 0/500, Mean loss: 0.00001424
#   Step 14500, Converged: 0/500, Mean loss: 0.00001329
#   Step 15000, Converged: 0/500, Mean loss: 0.00001249
#   Step 15500, Converged: 0/500, Mean loss: 0.00001185
#   Step 16000, Converged: 0/500, Mean loss: 0.00001135
#   Step 16500, Converged: 0/500, Mean loss: 0.00001086
#   Step 17000, Converged: 0/500, Mean loss: 0.00001041
#   Step 17500, Converged: 0/500, Mean loss: 0.00001006
#   Step 18000, Converged: 0/500, Mean loss: 0.00000967
#   Step 18500, Converged: 0/500, Mean loss: 0.00000926
#   Step 19000, Converged: 0/500, Mean loss: 0.00000901
#   Step 19500, Converged: 0/500, Mean loss: 0.00000881
#   Step 20000, Converged: 0/500, Mean loss: 0.00000853
#   Step 20500, Converged: 0/500, Mean loss: 0.00000841
#   Step 21000, Converged: 0/500, Mean loss: 0.00000817
#   Step 21500, Converged: 0/500, Mean loss: 0.00000803
#   Step 22000, Converged: 0/500, Mean loss: 0.00000783
#   Step 22500, Converged: 0/500, Mean loss: 0.00000761
#   Step 23000, Converged: 0/500, Mean loss: 0.00000750
#   Step 23500, Converged: 0/500, Mean loss: 0.00000736
#   Step 24000, Converged: 0/500, Mean loss: 0.00000721
#   Step 24500, Converged: 0/500, Mean loss: 0.00000709
#   Step 25000, Converged: 0/500, Mean loss: 0.00000699
#   Step 25500, Converged: 0/500, Mean loss: 0.00000696
#   Step 26000, Converged: 0/500, Mean loss: 0.00000680
#   Step 26500, Converged: 0/500, Mean loss: 0.00000669
#   Step 27000, Converged: 0/500, Mean loss: 0.00000657
#   Step 27500, Converged: 0/500, Mean loss: 0.00000647
#   Step 28000, Converged: 0/500, Mean loss: 0.00000635
#   Step 28500, Converged: 0/500, Mean loss: 0.00000633
#   Step 29000, Converged: 0/500, Mean loss: 0.00000623
#   Step 29500, Converged: 0/500, Mean loss: 0.00000616
#   Step 30000, Converged: 0/500, Mean loss: 0.00000608
#   Step 30500, Converged: 0/500, Mean loss: 0.00000607
#   Step 31000, Converged: 0/500, Mean loss: 0.00000601
#   Step 31500, Converged: 0/500, Mean loss: 0.00000588
#   Step 32000, Converged: 0/500, Mean loss: 0.00000589
#   Step 32500, Converged: 0/500, Mean loss: 0.00000583
#   Step 33000, Converged: 0/500, Mean loss: 0.00000569
#   Step 33500, Converged: 0/500, Mean loss: 0.00000565
#   Step 34000, Converged: 0/500, Mean loss: 0.00000565
#   Step 34500, Converged: 0/500, Mean loss: 0.00000557
#   Step 35000, Converged: 0/500, Mean loss: 0.00000547
#   Step 35500, Converged: 0/500, Mean loss: 0.00000540
#   Step 36000, Converged: 0/500, Mean loss: 0.00000547
#   Step 36500, Converged: 0/500, Mean loss: 0.00000541
#   Step 37000, Converged: 0/500, Mean loss: 0.00000537
#   Step 37500, Converged: 0/500, Mean loss: 0.00000520
#   Step 38000, Converged: 0/500, Mean loss: 0.00000521
#   Step 38500, Converged: 0/500, Mean loss: 0.00000519
#   Step 39000, Converged: 0/500, Mean loss: 0.00000516
#   Step 39500, Converged: 0/500, Mean loss: 0.00000507
#   Step 40000, Converged: 0/500, Mean loss: 0.00000509
#   Step 40500, Converged: 0/500, Mean loss: 0.00000503
#   Step 41000, Converged: 0/500, Mean loss: 0.00000493
#   Step 41500, Converged: 0/500, Mean loss: 0.00000497
#   Step 42000, Converged: 0/500, Mean loss: 0.00000490
#   Step 42500, Converged: 0/500, Mean loss: 0.00000486
#   Step 43000, Converged: 0/500, Mean loss: 0.00000489
#   Step 43500, Converged: 0/500, Mean loss: 0.00000480
#   Step 44000, Converged: 0/500, Mean loss: 0.00000476
#   Step 44500, Converged: 0/500, Mean loss: 0.00000480
#   Step 45000, Converged: 0/500, Mean loss: 0.00000467
#   Step 45500, Converged: 0/500, Mean loss: 0.00000459
#   Step 46000, Converged: 0/500, Mean loss: 0.00000459
#   Step 46500, Converged: 0/500, Mean loss: 0.00000462
#   Step 47000, Converged: 0/500, Mean loss: 0.00000458
#   Step 47500, Converged: 0/500, Mean loss: 0.00000457
#   Step 48000, Converged: 0/500, Mean loss: 0.00000451
#   Step 48500, Converged: 0/500, Mean loss: 0.00000447
#   Step 49000, Converged: 0/500, Mean loss: 0.00000440
#   Step 49500, Converged: 0/500, Mean loss: 0.00000440
#   Step 50000, Converged: 0/500, Mean loss: 0.00000437
#   Step 50500, Converged: 0/500, Mean loss: 0.00000441
#   Step 51000, Converged: 0/500, Mean loss: 0.00000438
#   Step 51500, Converged: 0/500, Mean loss: 0.00000429
#   Step 52000, Converged: 0/500, Mean loss: 0.00000432
#   Step 52500, Converged: 0/500, Mean loss: 0.00000421
#   Step 53000, Converged: 0/500, Mean loss: 0.00000422
#   Step 53500, Converged: 0/500, Mean loss: 0.00000420
#   Step 54000, Converged: 0/500, Mean loss: 0.00000420
#   Step 54500, Converged: 0/500, Mean loss: 0.00000418
#   Step 55000, Converged: 0/500, Mean loss: 0.00000413
#   Step 55500, Converged: 0/500, Mean loss: 0.00000415
#   Step 56000, Converged: 0/500, Mean loss: 0.00000409
#   Step 56500, Converged: 0/500, Mean loss: 0.00000410
#   Step 57000, Converged: 0/500, Mean loss: 0.00000408
#   Step 57500, Converged: 0/500, Mean loss: 0.00000400
#   Step 58000, Converged: 0/500, Mean loss: 0.00000403
#   Step 58500, Converged: 0/500, Mean loss: 0.00000400
#   Step 59000, Converged: 0/500, Mean loss: 0.00000396
#   Step 59500, Converged: 0/500, Mean loss: 0.00000402
#   Final: 0/500 converged
#
# ============================================================
# SUMMARY: Found 0 unique fixed points
# ============================================================
#
# No fixed points found.
# (0, 64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[315], line 9
#       7 fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=500)
#       8 print(fixed_points.shape)
# ----> 9 plot_trajectory(0, 2000)
#
# Cell In[310], line 13, in plot_trajectory(start, end)
#      10 cmap = plt.cm.viridis
#      11 norm = Normalize(vmin=0, vmax=end-start)
# ---> 13 print(pca.transform(fixed_points)[0, :8])
#      15 for k in np.arange(0, 8, 2):
#      16     k_x, k_y = int(k/4), int(k/2) % 2
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/decomposition/_base.py:138, in _BasePCA.transform(self, X)
#     134 xp, _ = get_namespace(X, self.components_, self.explained_variance_)
#     136 check_is_fitted(self)
# --> 138 X = validate_data(
#     139     self,
#     140     X,
#     141     dtype=[xp.float64, xp.float32],
#     142     accept_sparse=("csr", "csc"),
#     143     reset=False,
#     144 )
#     145 return self._transform(X, xp=xp, x_is_centered=False)
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/validation.py:1130, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1128     n_samples = _num_samples(array)
#    1129     if n_samples < ensure_min_samples:
# -> 1130         raise ValueError(
#    1131             "Found array with %d sample(s) (shape=%s) while a"
#    1132             " minimum of %d is required%s."
#    1133             % (n_samples, array.shape, ensure_min_samples, context)
#    1134         )
#    1136 if ensure_min_features > 0 and array.ndim == 2:
#    1137     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 64)) while a minimum of 1 is required by PCA.

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[1].set(1)
input_vec = input_vec.at[5].set(1)
input_vec = input_vec.at[6].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=1500)
print(fixed_points.shape)
plot_trajectory(0, 2000)
# Out:
# Searching for fixed points (1500 attempts)...
#
#   Step    0, Converged: 0/1500, Mean loss: 1.95863414
#   Step  500, Converged: 0/1500, Mean loss: 0.09015454
#   Step 1000, Converged: 0/1500, Mean loss: 0.02511295
#   Step 1500, Converged: 0/1500, Mean loss: 0.01128721
#   Step 2000, Converged: 0/1500, Mean loss: 0.00623867
#   Step 2500, Converged: 0/1500, Mean loss: 0.00388837
#   Step 3000, Converged: 0/1500, Mean loss: 0.00261960
#   Step 3500, Converged: 0/1500, Mean loss: 0.00185666
#   Step 4000, Converged: 0/1500, Mean loss: 0.00136135
#   Step 4500, Converged: 0/1500, Mean loss: 0.00102174
#   Step 5000, Converged: 0/1500, Mean loss: 0.00077891
#   Step 5500, Converged: 0/1500, Mean loss: 0.00059992
#   Step 6000, Converged: 0/1500, Mean loss: 0.00046581
#   Step 6500, Converged: 0/1500, Mean loss: 0.00036444
#   Step 7000, Converged: 0/1500, Mean loss: 0.00028687
#   Step 7500, Converged: 0/1500, Mean loss: 0.00022682
#   Step 8000, Converged: 0/1500, Mean loss: 0.00018016
#   Step 8500, Converged: 0/1500, Mean loss: 0.00014379
#   Step 9000, Converged: 0/1500, Mean loss: 0.00011535
#   Step 9500, Converged: 0/1500, Mean loss: 0.00009307
#   Step 10000, Converged: 0/1500, Mean loss: 0.00007550
#   Step 10500, Converged: 0/1500, Mean loss: 0.00006162
#   Step 11000, Converged: 0/1500, Mean loss: 0.00005069
#   Step 11500, Converged: 0/1500, Mean loss: 0.00004209
#   Step 12000, Converged: 0/1500, Mean loss: 0.00003535
#   Step 12500, Converged: 0/1500, Mean loss: 0.00003003
#   Step 13000, Converged: 0/1500, Mean loss: 0.00002584
#   Step 13500, Converged: 0/1500, Mean loss: 0.00002250
#   Step 14000, Converged: 0/1500, Mean loss: 0.00001984
#   Step 14500, Converged: 0/1500, Mean loss: 0.00001771
#   Step 15000, Converged: 0/1500, Mean loss: 0.00001596
#   Step 15500, Converged: 0/1500, Mean loss: 0.00001450
#   Step 16000, Converged: 0/1500, Mean loss: 0.00001331
#   Step 16500, Converged: 0/1500, Mean loss: 0.00001232
#   Step 17000, Converged: 0/1500, Mean loss: 0.00001143
#   Step 17500, Converged: 0/1500, Mean loss: 0.00001067
#   Step 18000, Converged: 0/1500, Mean loss: 0.00001007
#   Step 18500, Converged: 0/1500, Mean loss: 0.00000948
#   Step 19000, Converged: 0/1500, Mean loss: 0.00000900
#   Step 19500, Converged: 0/1500, Mean loss: 0.00000851
#   Step 20000, Converged: 0/1500, Mean loss: 0.00000812
#   Step 20500, Converged: 0/1500, Mean loss: 0.00000777
#   Step 21000, Converged: 0/1500, Mean loss: 0.00000745
#   Step 21500, Converged: 0/1500, Mean loss: 0.00000715
#   Step 22000, Converged: 0/1500, Mean loss: 0.00000685
#   Step 22500, Converged: 0/1500, Mean loss: 0.00000662
#   Step 23000, Converged: 0/1500, Mean loss: 0.00000636
#   Step 23500, Converged: 0/1500, Mean loss: 0.00000615
#   Step 24000, Converged: 0/1500, Mean loss: 0.00000596
#   Step 24500, Converged: 0/1500, Mean loss: 0.00000576
#   Step 25000, Converged: 0/1500, Mean loss: 0.00000557
#   Step 25500, Converged: 0/1500, Mean loss: 0.00000544
#   Step 26000, Converged: 0/1500, Mean loss: 0.00000525
#   Step 26500, Converged: 0/1500, Mean loss: 0.00000513
#   Step 27000, Converged: 0/1500, Mean loss: 0.00000498
#   Step 27500, Converged: 0/1500, Mean loss: 0.00000486
#   Step 28000, Converged: 0/1500, Mean loss: 0.00000472
#   Step 28500, Converged: 0/1500, Mean loss: 0.00000462
#   Step 29000, Converged: 0/1500, Mean loss: 0.00000449
#   Step 29500, Converged: 0/1500, Mean loss: 0.00000437
#   Step 30000, Converged: 0/1500, Mean loss: 0.00000429
#   Step 30500, Converged: 0/1500, Mean loss: 0.00000419
#   Step 31000, Converged: 0/1500, Mean loss: 0.00000410
#   Step 31500, Converged: 0/1500, Mean loss: 0.00000398
#   Step 32000, Converged: 0/1500, Mean loss: 0.00000392
#   Step 32500, Converged: 0/1500, Mean loss: 0.00000382
#   Step 33000, Converged: 0/1500, Mean loss: 0.00000380
#   Step 33500, Converged: 0/1500, Mean loss: 0.00000369
#   Step 34000, Converged: 0/1500, Mean loss: 0.00000358
#   Step 34500, Converged: 0/1500, Mean loss: 0.00000353
#   Step 35000, Converged: 0/1500, Mean loss: 0.00000349
#   Step 35500, Converged: 0/1500, Mean loss: 0.00000343
#   Step 36000, Converged: 0/1500, Mean loss: 0.00000338
#   Step 36500, Converged: 0/1500, Mean loss: 0.00000332
#   Step 37000, Converged: 0/1500, Mean loss: 0.00000328
#   Step 37500, Converged: 0/1500, Mean loss: 0.00000320
#   Step 38000, Converged: 0/1500, Mean loss: 0.00000316
#   Step 38500, Converged: 0/1500, Mean loss: 0.00000312
#   Step 39000, Converged: 0/1500, Mean loss: 0.00000308
#   Step 39500, Converged: 0/1500, Mean loss: 0.00000300
#   Step 40000, Converged: 0/1500, Mean loss: 0.00000299
#   Step 40500, Converged: 0/1500, Mean loss: 0.00000292
#   Step 41000, Converged: 0/1500, Mean loss: 0.00000290
#   Step 41500, Converged: 0/1500, Mean loss: 0.00000287
#   Step 42000, Converged: 0/1500, Mean loss: 0.00000281
#   Step 42500, Converged: 0/1500, Mean loss: 0.00000277
#   Step 43000, Converged: 0/1500, Mean loss: 0.00000273
#   Step 43500, Converged: 0/1500, Mean loss: 0.00000272
#   Step 44000, Converged: 0/1500, Mean loss: 0.00000268
#   Step 44500, Converged: 0/1500, Mean loss: 0.00000266
#   Step 45000, Converged: 0/1500, Mean loss: 0.00000261
#   Step 45500, Converged: 0/1500, Mean loss: 0.00000257
#   Step 46000, Converged: 0/1500, Mean loss: 0.00000254
#   Step 46500, Converged: 0/1500, Mean loss: 0.00000248
#   Step 47000, Converged: 0/1500, Mean loss: 0.00000246
#   Step 47500, Converged: 0/1500, Mean loss: 0.00000246
#   Step 48000, Converged: 0/1500, Mean loss: 0.00000243
#   Step 48500, Converged: 0/1500, Mean loss: 0.00000242
#   Step 49000, Converged: 0/1500, Mean loss: 0.00000238
#   Step 49500, Converged: 0/1500, Mean loss: 0.00000234
#   Step 50000, Converged: 0/1500, Mean loss: 0.00000233
#   Step 50500, Converged: 0/1500, Mean loss: 0.00000230
#   Step 51000, Converged: 0/1500, Mean loss: 0.00000226
#   Step 51500, Converged: 0/1500, Mean loss: 0.00000225
#   Step 52000, Converged: 0/1500, Mean loss: 0.00000224
#   Step 52500, Converged: 0/1500, Mean loss: 0.00000224
#   Step 53000, Converged: 0/1500, Mean loss: 0.00000218
#   Step 53500, Converged: 0/1500, Mean loss: 0.00000217
#   Step 54000, Converged: 0/1500, Mean loss: 0.00000214
#   Step 54500, Converged: 0/1500, Mean loss: 0.00000214
#   Step 55000, Converged: 0/1500, Mean loss: 0.00000211
#   Step 55500, Converged: 0/1500, Mean loss: 0.00000211
#   Step 56000, Converged: 0/1500, Mean loss: 0.00000208
#   Step 56500, Converged: 0/1500, Mean loss: 0.00000209
#   Step 57000, Converged: 0/1500, Mean loss: 0.00000203
#   Step 57500, Converged: 0/1500, Mean loss: 0.00000202
#   Step 58000, Converged: 0/1500, Mean loss: 0.00000200
#   Step 58500, Converged: 0/1500, Mean loss: 0.00000200
#   Step 59000, Converged: 0/1500, Mean loss: 0.00000199
#   Step 59500, Converged: 0/1500, Mean loss: 0.00000194
#   Final: 0/1500 converged
#
# ============================================================
# SUMMARY: Found 0 unique fixed points
# ============================================================
#
# No fixed points found.
# (0, 64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[316], line 10
#       8 fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=1500)
#       9 print(fixed_points.shape)
# ---> 10 plot_trajectory(0, 2000)
#
# Cell In[310], line 13, in plot_trajectory(start, end)
#      10 cmap = plt.cm.viridis
#      11 norm = Normalize(vmin=0, vmax=end-start)
# ---> 13 print(pca.transform(fixed_points)[0, :8])
#      15 for k in np.arange(0, 8, 2):
#      16     k_x, k_y = int(k/4), int(k/2) % 2
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/decomposition/_base.py:138, in _BasePCA.transform(self, X)
#     134 xp, _ = get_namespace(X, self.components_, self.explained_variance_)
#     136 check_is_fitted(self)
# --> 138 X = validate_data(
#     139     self,
#     140     X,
#     141     dtype=[xp.float64, xp.float32],
#     142     accept_sparse=("csr", "csc"),
#     143     reset=False,
#     144 )
#     145 return self._transform(X, xp=xp, x_is_centered=False)
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File ~/anaconda3/envs/favorably_connected/lib/python3.11/site-packages/sklearn/utils/validation.py:1130, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1128     n_samples = _num_samples(array)
#    1129     if n_samples < ensure_min_samples:
# -> 1130         raise ValueError(
#    1131             "Found array with %d sample(s) (shape=%s) while a"
#    1132             " minimum of %d is required%s."
#    1133             % (n_samples, array.shape, ensure_min_samples, context)
#    1134         )
#    1136 if ensure_min_features > 0 and array.ndim == 2:
#    1137     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 64)) while a minimum of 1 is required by PCA.

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[1].set(1)
input_vec = input_vec.at[5].set(1)
input_vec = input_vec.at[6].set(1)

key = jax.random.PRNGKey(42)
indices = jax.random.randint(key, (200,), 0, traj_data['actor_hidden'].shape[0])
h_inits = traj_data['actor_hidden'][indices, :]

trajectories = run_states_forward(
    h_inits,
    input_vec,
    params,
    network,
    n_steps=500
)

print(trajectories.shape)

plot_trajectory(trajectories[:, -1, :])
# Out:
# (500, 200, 64)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[2].set(1)
input_vec = input_vec.at[5].set(1)
input_vec = input_vec.at[6].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=1500)
print(fixed_points.shape)
plot_trajectory(0, 2000)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[3].set(1)
input_vec = input_vec.at[5].set(1)
input_vec = input_vec.at[6].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=1500)
print(fixed_points.shape)
plot_trajectory(0, 2000)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[2].set(1)
input_vec = input_vec.at[5].set(1)
input_vec = input_vec.at[6].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, traj_data, params, network, CONFIG, n_attempts=500)
print(fixed_points.shape)
plot_trajectory(0, 2000)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[1].set(1)
input_vec = input_vec.at[5].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, n_attempts=100)

plot_trajectory(0, 2000)

# %%
# Example: neutral context
input_vec = jnp.zeros(input_dim)
input_vec = input_vec.at[0].set(1)
input_vec = input_vec.at[1].set(1)
input_vec = input_vec.at[5].set(1)
input_vec = input_vec.at[6].set(1)

fixed_points = find_and_plot_fixed_points(input_vec, n_attempts=100)

plot_trajectory(0, 2000)
